# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.decomposition import PCA

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Pre-processing

# %% [markdown]
# Get some general information about our data

# %%
df = pd.read_csv('../data/creditcard.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# *'Time' is a float representing seconds elapsed between each transaction and the first transaction in the dataset.*
# All values are floats, asside from 'Class'.

# %%
df.isna().any().all()
# Out:
# False

# %% [markdown]
# No null or NaN values.
#
# Vizualizing class imbalance

# %%
counts = df.Class.value_counts()
counts.plot(kind='bar', rot=1)

# %%
fraud = df[df.Class==1]
valid = df[df.Class==0]
print(len(fraud), len(valid))
# Out:
# 492 284315

# %% [markdown]
# We can get a sense of the imbalance also using the outlier fraction

# %%
outlier_fraction = len(fraud)/len(valid)
outlier_fraction
# Out:
# 0.0017304750013189597

# %% [markdown]
# Explore 'Amount' w/in fraud and non_fraud dataframes

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Upon first glance fraudulent charges are, on average, larger than non-fraudulent charges.  However, the fraudulent charges in the dataset do not exceed a certain value (2125.87).

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.hist(fraud.Amount, bins=50)
ax.set_title('Fraud')
plt.xlabel('Amount ($)')
plt.ylabel('No. Transactions')
plt.xlim((0,20000))
plt.yscale('log')

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.hist(valid.Amount, bins=50)
ax.set_title('Non-Fraud')
plt.xlabel('Amount ($)')
plt.ylabel('No. Transactions')
plt.xlim((0,20000))
plt.yscale('log')

# %% [markdown]
# Take a look at correlations

# %%
corr = df.corr()
sns.heatmap(corr)

# %%
high_corr = corr[corr > 0.05]
#V2, V4, V11 all higher correlation w Class

# %%
sns.pairplot(df[['Class', 'V2', 'V4', 'V11', 'Amount']], hue='Class')

# %% [markdown]
# # Preprocessing and Modeling

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Split independent & dependent variables

# %%
state = np.random.RandomState(42)
X = df.drop('Class', axis=1)
y = df.Class
X_outliers = state.uniform(low=0, high=1, size=(X.shape[0], X.shape[1]))

# %% [markdown]
# Train / test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=state)

# %% [markdown]
# Verify successful stratify on Y

# %%
y_train.value_counts()[1]/y_train.value_counts()[0], y_test.value_counts()[1]/y_test.value_counts()[0]
# Out:
# (0.0017304770301450037, 0.0017304689148693708)

# %% [markdown]
# ### IFA

# %% [markdown]
# Train and evaluate base Isolation Forest Algorithm

# %%
IFA = IsolationForest(n_estimators=100, contamination=outlier_fraction, random_state=state, max_samples=len(X_train), bootstrap=True)
IFA.fit(X_train, y_train)

# classification_report(y_test, y_pred)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=True,
#                 contamination=0.0017304750013189597, max_features=1.0,
#                 max_samples=213605, n_estimators=100, n_jobs=None,
#                 random_state=<mtrand.RandomState object at 0x1a20542828>,
#                 verbose=0, warm_start=False)

# %%
y_pred = IFA.predict(X_test)

# %%
Counter(y_pred)
# Out:
# Counter({1: 71072, -1: 130})

# %%
def reformat_IFA_predictions(y_pred):
    return [0 if x==1 else 1 for x in y_pred]

# %%
def reformat_y_for_gs(y_train):
    return [-1 if x==1 else 1 for x in y_train]

# %%
y_pred = reformat_IFA_predictions(y_pred)

# %%
print(Counter(y_pred))
print(Counter(y_test))
# Out:
# Counter({0: 71072, 1: 130})
# Counter({0: 71079, 1: 123})

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.26      0.28      0.27       123
#
#     accuracy                           1.00     71202
#    macro avg       0.63      0.64      0.63     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
f1_score(y_test, y_pred)
# Out:
# 0.26877470355731226

# %%
params = {
    'n_estimators': [20,100],
    'bootstrap': [True, False],
    'max_features': [1,3,5,10]
}

ifa_gs1 = GridSearchCV(IFA, params,scoring='f1',verbose=1)
ifa_gs1.fit(X_train, reformat_y_for_gs(y_train))

# %%
ifa_gs1.best_params_
# Out:
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}

# %%
params = {
    'n_estimators': [20],
    'bootstrap': [True, False],
    'max_features': [5,10,15,len(X.columns)]
}

ifa_gs2 = GridSearchCV(IFA, params,scoring='f1',verbose=2)
ifa_gs2.fit(X_train, reformat_y_for_gs(y_train))

# %%
ifa_gs2.best_params_
# Out:
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 20}

# %%
IFA_tuned = IsolationForest(n_estimators=20, max_features=20, bootstrap=False)
IFA_tuned.fit(X_train, y_train)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination='auto',
#                 max_features=20, max_samples='auto', n_estimators=20,
#                 n_jobs=None, random_state=None, verbose=0, warm_start=False)

# %%
y_pred = reformat_IFA_predictions(IFA_tuned.predict(X_test))
print(classification_report(y_test, y_pred))
print(f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98     71079
#            1       0.03      0.82      0.06       123
#
#     accuracy                           0.95     71202
#    macro avg       0.51      0.89      0.52     71202
# weighted avg       1.00      0.95      0.97     71202
#
# 0.05626740947075209

# %% [markdown]
# ### LOF

# %%
LOF = LocalOutlierFactor(n_neighbors=20, 
                         leaf_size=30, 
                         metric='minkowski', 
                         p=2, 
                         metric_params=None,
                        contamination=outlier_fraction)
y_pred = LOF.fit_predict(X_train, y_train)

# %%
y_pred = reformat_IFA_predictions(y_pred)
print(classification_report(y_train, y_pred))
print(f1_score(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.00      0.00    213236
#            1       0.00      0.96      0.00       369
#
#     accuracy                           0.00    213605
#    macro avg       0.48      0.48      0.00    213605
# weighted avg       0.96      0.00      0.00    213605
#
# 0.0033051815509072867

# %%
(y_pred == y_train).sum()/len(y_train)
# Out:
# 0.0033098476159265935

# %% [markdown]
# ### Random Forest

# %%
rfc = RandomForestClassifier(n_estimators=20)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rfc.predict(X_test)
print(classification_report(y_test, y_pred))
print(f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.97      0.79      0.87       123
#
#     accuracy                           1.00     71202
#    macro avg       0.98      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
#
# 0.8699551569506726

# %%
params = {
    'n_estimators':[20],
    'min_samples_split':[2,3,4],
    'max_features':['auto', 'sqrt', 'log2']
}

rfc_gs1 = GridSearchCV(rfc, params, scoring='f1', verbose=2)
rfc_gs1.fit(X, y)
rfc_gs1.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_features=auto, min_samples_split=2, n_estimators=20 .........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_features=auto, min_samples_split=2, n_estimators=20, total=  34.8s
# [CV] max_features=auto, min_samples_split=2, n_estimators=20 .........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   34.8s remaining:    0.0s
# [CV]  max_features=auto, min_samples_split=2, n_estimators=20, total=  32.8s
# [CV] max_features=auto, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=2, n_estimators=20, total=  32.0s
# [CV] max_features=auto, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=2, n_estimators=20, total=  33.0s
# [CV] max_features=auto, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=2, n_estimators=20, total=  31.5s
# [CV] max_features=auto, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=3, n_estimators=20, total=  35.2s
# [CV] max_features=auto, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=3, n_estimators=20, total=  34.8s
# [CV] max_features=auto, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=3, n_estimators=20, total=  32.7s
# [CV] max_features=auto, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=3, n_estimators=20, total=  31.6s
# [CV] max_features=auto, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=3, n_estimators=20, total=  31.2s
# [CV] max_features=auto, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=4, n_estimators=20, total=  34.4s
# [CV] max_features=auto, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=4, n_estimators=20, total=  35.1s
# [CV] max_features=auto, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=4, n_estimators=20, total=  34.2s
# [CV] max_features=auto, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=4, n_estimators=20, total=  29.9s
# [CV] max_features=auto, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=auto, min_samples_split=4, n_estimators=20, total=  31.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=20, total=  36.7s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=20, total=  33.4s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=20, total=  30.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=20, total=  30.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=20, total=  28.8s
# [CV] max_features=sqrt, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=3, n_estimators=20, total=  34.3s
# [CV] max_features=sqrt, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=3, n_estimators=20, total=  34.4s
# [CV] max_features=sqrt, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=3, n_estimators=20, total=  34.3s
# [CV] max_features=sqrt, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=3, n_estimators=20, total=  31.9s
# [CV] max_features=sqrt, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=3, n_estimators=20, total=  30.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=20, total=  36.5s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=20, total=  31.4s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=20, total=  31.8s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=20, total=  30.7s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=20, total=  31.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=2, n_estimators=20, total=  28.0s
# [CV] max_features=log2, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=2, n_estimators=20, total=  26.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=2, n_estimators=20, total=  25.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=2, n_estimators=20, total=  24.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=2, n_estimators=20, total=  24.0s
# [CV] max_features=log2, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=3, n_estimators=20, total=  30.2s
# [CV] max_features=log2, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=3, n_estimators=20, total=  25.8s
# [CV] max_features=log2, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=3, n_estimators=20, total=  25.9s
# [CV] max_features=log2, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=3, n_estimators=20, total=  25.4s
# [CV] max_features=log2, min_samples_split=3, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=3, n_estimators=20, total=  25.5s
# [CV] max_features=log2, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=4, n_estimators=20, total=  31.8s
# [CV] max_features=log2, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=4, n_estimators=20, total=  27.5s
# [CV] max_features=log2, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=4, n_estimators=20, total=  29.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=4, n_estimators=20, total=  26.1s
# [CV] max_features=log2, min_samples_split=4, n_estimators=20 .........
# [CV]  max_features=log2, min_samples_split=4, n_estimators=20, total=  29.3s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 23.1min finished
# {'max_features': 'sqrt', 'min_samples_split': 4, 'n_estimators': 20}

# %%
rfc = RandomForestClassifier(max_features='sqrt', min_samples_split=4)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rfc.predict(X_test)
print((Counter(y_pred)))
print(Counter(y_test))
# Out:
# Counter({0: 71102, 1: 100})
# Counter({0: 71079, 1: 123})

# %%
print(f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8699551569506726
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.97      0.79      0.87       123
#
#     accuracy                           1.00     71202
#    macro avg       0.98      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
